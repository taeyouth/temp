# %% [markdown]
# ## 파이프라인 구축

# %%
import pandas as pd
import pdpipe as pdp

# %% [markdown]
# #### 캐글 데이터 USA 주택 가격

# %%
df = pd.read_csv('C:/Users/고태영/Downloads/USA_Housing.csv')

# %%
df.describe().T
# Out:
#                                count          mean            std  \
# Avg. Area Income              5000.0  6.858311e+04   10657.991214
# Avg. Area House Age           5000.0  5.977222e+00       0.991456
# Avg. Area Number of Rooms     5000.0  6.987792e+00       1.005833
# Avg. Area Number of Bedrooms  5000.0  3.981330e+00       1.234137
# Area Population               5000.0  3.616352e+04    9925.650114
# Price                         5000.0  1.232073e+06  353117.626581
#
#                                        min            25%           50%  \
# Avg. Area Income              17796.631190   61480.562388  6.880429e+04
# Avg. Area House Age               2.644304       5.322283  5.970429e+00
# Avg. Area Number of Rooms         3.236194       6.299250  7.002902e+00
# Avg. Area Number of Bedrooms      2.000000       3.140000  4.050000e+00
# Area Population                 172.610686   29403.928702  3.619941e+04
# Price                         15938.657923  997577.135049  1.232669e+06
#
#                                        75%           max
# Avg. Area Income              7.578334e+04  1.077017e+05
# Avg. Area House Age           6.650808e+00  9.519088e+00
# Avg. Area Number of Rooms     7.665871e+00  1.075959e+01
# Avg. Area Number of Bedrooms  4.490000e+00  6.500000e+00
# Area Population               4.286129e+04  6.962171e+04
# Price                         1.471210e+06  2.469066e+06

# %% [markdown]
# #### House size column 생성

# %%
def size(n):
    if n <= 6.3 :
        return 'Small'
    elif 6.3 < n <= 7.7:
        return 'Medium'
    elif 7.7 < n :
        return 'Big'
    
df['House_size'] = df['Avg. Area Number of Rooms'].apply(size)

# %% [markdown]
# #### 열 제거 파이프라인 생성

# %%
drop_age = pdp.ColDrop('Avg. Area Number of Rooms')
df2 = drop_age(df)

# %%
df2.describe().T
# Out:
#                                count          mean            std  \
# Avg. Area Income              5000.0  6.858311e+04   10657.991214
# Avg. Area House Age           5000.0  5.977222e+00       0.991456
# Avg. Area Number of Bedrooms  5000.0  3.981330e+00       1.234137
# Area Population               5000.0  3.616352e+04    9925.650114
# Price                         5000.0  1.232073e+06  353117.626581
#
#                                        min            25%           50%  \
# Avg. Area Income              17796.631190   61480.562388  6.880429e+04
# Avg. Area House Age               2.644304       5.322283  5.970429e+00
# Avg. Area Number of Bedrooms      2.000000       3.140000  4.050000e+00
# Area Population                 172.610686   29403.928702  3.619941e+04
# Price                         15938.657923  997577.135049  1.232669e+06
#
#                                        75%           max
# Avg. Area Income              7.578334e+04  1.077017e+05
# Avg. Area House Age           6.650808e+00  9.519088e+00
# Avg. Area Number of Bedrooms  4.490000e+00  6.500000e+00
# Area Population               4.286129e+04  6.962171e+04
# Price                         1.471210e+06  2.469066e+06

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Bedrooms  5000 non-null   float64
#  3   Area Population               5000 non-null   float64
#  4   Price                         5000 non-null   float64
#  5   Address                       5000 non-null   object
#  6   House_size                    5000 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 273.6+ KB

# %% [markdown]
# &nbsp;

# %% [markdown]
# #### 파이프라인 추가 및 제거

# %% [markdown]
# 열 삭제 + 원핫인코딩 파이프라인

# %%
pipeline = pdp.ColDrop('Avg. Area Number of Rooms')
pipeline += pdp.OneHotEncode('House_size')

df3 = pipeline(df)

# %%
df3.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population         Price  \
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05
#
#                                              Address  House_size_Medium  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                  1
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                  1
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                  0
# 3                          USS Barnett\nFPO AP 44820                  0
# 4                         USNS Raymond\nFPO AE 09386                  0
#
#    House_size_Small
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %% [markdown]
# 로우 삭제 파이프라인

# %%
# 주택가격이 250000 이하면 drop, 초과면 keep 태그 표시
def price_tag(x):
    if x > 250000 :
        return 'keep'
    else :
        return 'drop'

# %%
# 태그 표시 함수 적용하는 파이프라인 객체 적용
pipeline += pdp.ApplyByCols('Price', price_tag, 'Price_tag', drop = False)
df4 = pipeline(df)

# %%
print('df 로우 수 :',len(df),'\ndf4 로우 수 :',len(df4),sep='')
# Out:
# df 로우 수 :5000
# df4 로우 수 :5000

# %%
df4.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population         Price Price_tag  \
# 0     23086.800503  1.059034e+06      keep
# 1     40173.072174  1.505891e+06      keep
# 2     36882.159400  1.058988e+06      keep
# 3     34310.242831  1.260617e+06      keep
# 4     26354.109472  6.309435e+05      keep
#
#                                              Address  House_size_Medium  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                  1
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                  1
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                  0
# 3                          USS Barnett\nFPO AP 44820                  0
# 4                         USNS Raymond\nFPO AE 09386                  0
#
#    House_size_Small
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %%
# ValDrop 메소드로 price tag가 drop인 row 삭제
pipeline += pdp.ValDrop(['drop'], 'Price_tag')
df5 = pipeline(df)
print('df 로우 수 :',len(df),'\ndf5 로우 수 :',len(df5),sep=' ')
# Out:
# df 로우 수 : 5000
# df5 로우 수 : 4990

# %%
df5.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population         Price Price_tag  \
# 0     23086.800503  1.059034e+06      keep
# 1     40173.072174  1.505891e+06      keep
# 2     36882.159400  1.058988e+06      keep
# 3     34310.242831  1.260617e+06      keep
# 4     26354.109472  6.309435e+05      keep
#
#                                              Address  House_size_Medium  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                  1
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                  1
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                  0
# 3                          USS Barnett\nFPO AP 44820                  0
# 4                         USNS Raymond\nFPO AE 09386                  0
#
#    House_size_Small
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %%
# price tag column 삭제
pipeline += pdp.ColDrop('Price_tag')
df6 = pipeline(df)
df6.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Bedrooms  \
# 0      79545.458574             5.682861                          4.09
# 1      79248.642455             6.002900                          3.09
# 2      61287.067179             5.865890                          5.13
# 3      63345.240046             7.188236                          3.26
# 4      59982.197226             5.040555                          4.23
#
#    Area Population         Price  \
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05
#
#                                              Address  House_size_Medium  \
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...                  1
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...                  1
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...                  0
# 3                          USS Barnett\nFPO AP 44820                  0
# 4                         USNS Raymond\nFPO AE 09386                  0
#
#    House_size_Small
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %%
def extract_state(token):
    return str(token[-2])

pipeline_tokenizer = pdp.TokenizeWords('Address')
pipeline_state = pdp.ApplyByCols('Address', extract_state, result_columns='State')
pipeline_state_extract = pipeline_tokenizer + pipeline_state
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-bcc20b0c3494> in <module>
#       2     return str(token[-2])
#       3
# ----> 4 pipeline_tokenizer = pdp.TokenizeWords('Address')
#       5 pipeline_state = pdp.ApplyByCols('Address', extract_state, result_columns='State')
#       6 pipeline_state_extract = pipeline_tokenizer + pipeline_state
#
# AttributeError: module 'pdpipe' has no attribute 'TokenizeWords'
